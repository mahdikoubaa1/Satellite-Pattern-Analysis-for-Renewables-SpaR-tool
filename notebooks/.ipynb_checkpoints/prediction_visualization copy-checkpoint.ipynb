# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
sys.path.append("../")
from utils.tool_utils import interactive_tool
data_path='/mnt/9TB/koubaa/23_06_26_09'
config_path='../data/pixnn'
dataset_path='../data/dataset'
tool=interactive_tool(dataset_path,config_path,data_path)
# Out:
# GeoData(data={'type': 'FeatureCollection', 'features': []}, hover_style={'fillColor': 'red', 'fillOpacity': 0.2}, name='masks_predicted', style={'color': 'yellow', 'fillColor': 'yellow', 'fillOpacity': 0.2})
# memory allocated:0.001056671142578125/ memory reserved:11.376953125
# Map(center=[51.216504, 12.028699], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…
# ...
